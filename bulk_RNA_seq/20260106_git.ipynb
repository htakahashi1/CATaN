# %%
#https://qiita.com/dk-math/items/0828de3f3b214229baf7
/bin/bash -c "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/HEAD/install.sh)"
brew install git-lfs
git lfs install 
git lfs track "*.txt"
→ただし、1Gを超えていたのでできなかった。
