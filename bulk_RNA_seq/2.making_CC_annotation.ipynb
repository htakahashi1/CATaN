# %% [markdown]
# # align CC score to SNPs

# %%
#export PATH=/home/ha7477/tools/miniconda3/envs/atac1b/bin:${PATH}
wd_path=<path_to_codes>
cd ${wd_path}
mkdir log
cd log

data_path=<path_to_your_data>
save_path=<path_to_output_file>

for CC in CC1_rotation CC2_rotation CC3_rotation CC4_rotation CC5_rotation CC6_rotation CC7_rotation CC8_rotation CC9_rotation CC10_rotation
do
qsub -pe def_slot 1 \
   -l s_vmem=4G \
   -cwd \
    /home/imgtaka/CCA_github_code/align_CCscore_to_SNPs.sh ${CC} ${data_path} ${save_path} 
done

# %%
for CC in CC1_rotation CC2_rotation CC3_rotation CC4_rotation CC5_rotation CC6_rotation CC7_rotation CC8_rotation CC9_rotation CC10_rotation
do
cd ${data_path}/TFpeak_noexp/observed/${CC} 
cat *_target_all_SNP_sort.bed.gz > all_target_all_SNP_sort.bed.gz
done

# %%
cd ${data_path}/log

for CC in CC1_rotation CC2_rotation CC3_rotation CC4_rotation CC5_rotation CC6_rotation CC7_rotation CC8_rotation CC9_rotation CC10_rotation
do
qsub -pe def_slot 4 \
   -l s_vmem=10G \
   -cwd /home/imgtaka/CCA_github_code/top_bottom_10percent_SNPs.sh ${CC} ${data_path} 
done
