# %% [markdown]
# ## S-LDSC step1

# %% [markdown]
# ## making the list of file names

# %%
data_path=<path_do_data>
data_f=${data_path}/CC_10percent_SNP_noexp_2
cd ${data_f}
mkdir ${data_f}/info
(ls *.bed.gz | sed -e 's/.bed.gz//g')> ${data_f}/info/data_list

# %%
#hg19
code_path=<path_to_code>

qlogin  -l s_vmem=10G -l mem_req=10G
export MKL_NUM_THREADS=1
export OMP_NUM_THREADS=1
export MKL_DOMAIN_NUM_THREADS=1
unset PROMPT_COMMAND



cd ${code_path}
mkdir -p log

export PATH=/home/imgishi/miniconda3/envs/ldsc/bin:${PATH}

dd={data_path}/CC_10percent_SNP_noexp_2

info=${dd}/info/data_list
num=`wc -l $info |  cut -d " " -f1`


#####STEP1: LD Score (EUR)
 #MAIN JOB

qsub -pe def_slot 1 \
   -l s_vmem=10G,mem_req=10G \
   -cwd \
   -t 1:${num} -tc 50 \
   -o log/sldsc_eur.log \
   -e log/sldsc_eur.error \
   ${code}/ldscore_eur_ver1.sh ${dd} 


dd=${data_path}/CC_10percent_SNP_noexp_2

info=${dd}/info/data_list
num=`wc -l $info |  cut -d " " -f1`


#####STEP2: LD Score (EUR)
 #MAIN JOB

qsub -pe def_slot 1 \
   -l s_vmem=10G,mem_req=10G \
   -cwd \
   -t 1:${num} -tc 100 \
   -o log/sldsc_eur_2.log \
   -e log/sldsc_eur_2.error \
   ${code_patha}/sldsc_eur-alltrait.sh ${dd}

# %%
data_f=${data_path}/CC_10percent_SNP_noexp_2_EAS
cd ${data_f}
mkdir ${data_f}/info
(ls *.bed.gz | sed -e 's/.bed.gz//g')> ${data_f}/info/data_list



qlogin  -l s_vmem=10G -l mem_req=10G
export MKL_NUM_THREADS=1
export OMP_NUM_THREADS=1
export MKL_DOMAIN_NUM_THREADS=1
unset PROMPT_COMMAND


cd ${code_path}
mkdir -p log


export PATH=/home/imgishi/miniconda3/envs/ldsc/bin:${PATH}




dd=${data_path}/CC_10percent_SNP_noexp_2_EAS

info=${dd}/info/data_list
num=`wc -l $info |  cut -d " " -f1`


#####STEP1-1: LD Score (EAS)

 #MAIN JOB

qsub -pe def_slot 1 \
   -l s_vmem=10G,mem_req=10G \
   -cwd \
   -t 1:${num} -tc 50 \
   -o log/sldsc_eas_2.log \
   -e log/sldsc_eas_2.error \
   ${code_path}/ldscore_eas.sh ${dd} 



dd=${data_path}/CC_10percent_SNP_noexp_2_EAS

info=${dd}/info/data_list
num=`wc -l $info |  cut -d " " -f1`


#####STEP1-1: LD Score (EUR)

 #MAIN JOB

qsub -pe def_slot 1 \
   -l s_vmem=10G,mem_req=10G \
   -cwd \
   -t 1:${num} -tc 100 \
   -o log/sldsc_eas_3.log \
   -e log/sldsc_eas_3.error \
   ${code_path}/sldsc_eas.sh ${dd}
